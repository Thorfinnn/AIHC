# %%
#Taher Barwaniwala
#BE-COMP
#Roll no 21

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# Define the URL of the webpage containing medical reviews
url = 'https://www.kokilabenhospital.com/patients/testimonials.html'  # Replace with your actual URL

# Set the user-agent header
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'}

# Send an HTTP GET request to the URL with the custom user-agent header
response = requests.get(url, headers=headers)

if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the elements that contain the reviews, adjust the selector based on your webpage's structure
    reviews = soup.find_all('div', class_='cont_box')  # You should adjust the selector to match your webpage structure

    # Initialize NLTK's sentiment analyzer
    sia = SentimentIntensityAnalyzer()

    for review in reviews:
        # Extract the review text
        review_text = review.find('p').text  # Adjust based on your webpage's structure

        # Tokenize the review text
        tokens = word_tokenize(review_text)

        # Remove stopwords
        stop_words = set(stopwords.words('english'))
        filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

        # Calculate sentiment scores
        sentiment_scores = sia.polarity_scores(review_text)

        print("Review Text:")
        print(review_text)
        print("\nTokens:")
        print(filtered_tokens)
        print("\nSentiment Scores:")
        print(sentiment_scores)
        print("\n---\n")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Review Text:
# Very good treatment. All doctors and staff are cooperative & helpful. Thanks
# Special thanks ...
#
# Tokens:
# ['good', 'treatment', '.', 'doctors', 'staff', 'cooperative', '&', 'helpful', '.', 'Thanks', 'Special', 'thanks', '...']
#
# Sentiment Scores:
# {'neg': 0.0, 'neu': 0.383, 'pos': 0.617, 'compound': 0.9259}
#
# ---
#
# Review Text:
# The entire staff at the gynaecology section are beyond fabulous! Made my birthing experience so fulf...
#
# Tokens:
# ['entire', 'staff', 'gynaecology', 'section', 'beyond', 'fabulous', '!', 'Made', 'birthing', 'experience', 'fulf', '...']
#
# Sentiment Scores:
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.5707}
#
# ---
#
# Review Text:
# My father (Ashokbhai J. Diyora, Age:56 years) underwent knee osteotomy surgery last year, and I cann...
#
# Tokens:
# ['father', '(', 'Ashokbhai', 'J.', 'Diyora', ',', 'Age:56', 'years', ')', 'underwent', 'knee', 'osteotomy', 'surgery', 'last', 'year', ',', 'cann', '...']
#
# ...
